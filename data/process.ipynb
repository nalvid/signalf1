# %%
from f1.livetiming.data import LiveTimingData

# %%
data = LiveTimingData("Monza.log")

# %%
data.list_categories()
# Out:
# ['CarData.z',
#  'Position.z',
#  'Heartbeat',
#  'WeatherData',
#  'RaceControlMessages',
#  'TrackStatus',
#  'SessionData',
#  'ExtrapolatedClock',
#  'DriverList',
#  'TopThree',
#  'TimingAppData',
#  'TimingData',
#  'TimingStats',
#  'LapCount']

# %%
data.get("TimingData")
# Out:
# [[datetime.timedelta(seconds=13, microseconds=125000),
#   {'Lines': {'1': {'Line': 2, 'Position': '2'},
#     '3': {'Line': 3, 'Position': '3'},
#     '4': {'Line': 4, 'Position': '4'},
#     '10': {'Line': 5, 'Position': '5'},
#     '11': {'Line': 6, 'Position': '6'},
#     '14': {'Line': 7, 'Position': '7'},
#     '16': {'Line': 8, 'Position': '8'},
#     '18': {'Line': 9, 'Position': '9'},
#     '20': {'Line': 10, 'Position': '10'},
#     '22': {'Line': 11, 'Position': '11'},
#     '23': {'Line': 12, 'Position': '12'},
#     '24': {'Line': 13, 'Position': '13'},
#     '27': {'Line': 14, 'Position': '14'},
#     '31': {'Line': 1,
#      'Position': '1',
#      'InPit': False,
#      'PitOut': True,
#      'Status': 96,
#      'NumberOfLaps': 1}}}],
#  [datetime.timedelta(seconds=13, microseconds=180000),
#   {'Lines': {'31': {'Status': 608}}}],
#  [datetime.timedelta(seconds=13, microseconds=196000),
# ...
